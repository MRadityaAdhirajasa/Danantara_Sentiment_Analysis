# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# credential yt = AIzaSyB4xYL9dOWPXSpFHDYA-_spDXIz8JTm_5M

# %% [markdown]
# ## Scrapping Data

# %%
# !pip install google-api-python-client pandas tqdm

# %%
import os
import pandas as pd
from googleapiclient.discovery import build
from tqdm import tqdm

API_KEY = "AIzaSyB4xYL9dOWPXSpFHDYA-_spDXIz8JTm_5M"

youtube = build("youtube", "v3", developerKey=API_KEY)

def get_youtube_comments(video_id, max_comments=100):
    comments = []
    next_page_token = None

    while len(comments) < max_comments:

        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            pageToken=next_page_token,
            maxResults=min(100, max_comments - len(comments)),  # Maks 100 per request
            textFormat="plainText"
        )
        response = request.execute()

        for item in response.get("items", []):
            comment = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "author": comment["authorDisplayName"],
                "comment": comment["textDisplay"],
                "like_count": comment["likeCount"],
                "published_at": comment["publishedAt"]
            })

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return comments

# # Contoh: Ambil komentar dari video Danantara (ganti dengan video ID yang sesuai)
# video_id = "ynDu3buS4g0"  # Ganti dengan ID video YouTube
# comments = get_youtube_comments(video_id, max_comments=2000)

# # Simpan ke dalam DataFrame
# df = pd.DataFrame(comments)
# df.to_csv("youtube_comments.csv", index=False)

video_ids = ["ynDu3buS4g0", "WyPLvwLK8c4", "_R-7AvNXxAM", "Tl6fDFA4xNI", "02_WTfYvQiE"]
all_comments = []

for vid in tqdm(video_ids):
    all_comments.extend(get_youtube_comments(vid, max_comments=5000))

df = pd.DataFrame(all_comments)
df.to_csv("youtube_multiple_comments.csv", index=False)

print(f"Scraping selesai! {len(df)} komentar disimpan ke 'youtube_multiple_comments.csv'.")
# Out:
# 100%|██████████| 5/5 [00:21<00:00,  4.22s/it]
# Scraping selesai! 9525 komentar disimpan ke 'youtube_multiple_comments.csv'.

# %% [markdown]
# Source:
#
#
#
# 1.   LIVE - Danantara VS Kepercayaan Publik, Rosan Roeslani Menjawab | ROSI - https://www.youtube.com/watch?v=ynDu3buS4g0
# 2.   Mengenal Apa Itu Danantara - https://www.youtube.com/watch?v=WyPLvwLK8c4
# 3.   [FULL] 'Komandan' Danantara, Siap Jaga Uang Negara | One On One tvOne - https://www.youtube.com/watch?v=_R-7AvNXxAM
# 4.   SURAT TERBUKA UNTUK DANANTARA - https://www.youtube.com/watch?v=Tl6fDFA4xNI
# 5.   Memahami Danantara dengan Mudah - https://www.youtube.com/watch?v=02_WTfYvQiE

# %%
df = pd.read_csv('youtube_multiple_comments.csv')

df
# Out:
#                       author  \
# 0     @EngineerBersamaSolusi
# 1      @uapariamanchanel7031
# 2             @lukmanjfr0355
# 3            @agusherman5289
# 4         @junaidiarsifa3813
# ...                      ...
# 9520            @FaisRakyati
# 9521       @arethadelaka8161
# 9522       @bagasramadhan548
# 9523           @jojosatorufm
# 9524       @andhikabagas7732
#
#                                                 comment  like_count  \
# 0     Yakinnn... Ingat para aparat yg makan uang har...           0
# 1     hanya hukum mati yang bisa membuat rakyat indo...           0
# 2     emng kalaupun kejadian(korupsi),,  kita bisa a...           0
# 3     Diem2 bae mahasiswa pada Demo demo gih.. Kok s...           0
# 4     Hanya minta transparansi saja kq berbelit beli...           0
# ...                                                 ...         ...
# 9520             AWAS AJA KALO SI DANA ITU MOKONDO!!!!!           0
# ...
